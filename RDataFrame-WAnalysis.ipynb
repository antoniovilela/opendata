# %%
import ROOT
ROOT.EnableImplicitMT()

# %%
dataset_path = "root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22"

import json
files = json.load( open( "WBosonAnalysis.json" ) )

lumi = 10064.0
print( 'Run on data corresponding to {:.2f} fb^-1'.format( lumi / 1000.0 ) )
# Out:
# Run on data corresponding to 10.06 fb^-1

# %%
processes = files.keys()
df = {}
xsecs = {}
sumws = {}
samples = []
for p in processes:
    for d in files[p]:
        # Construct the dataframes
        folder = d[0] # Folder name
        sample = d[1] # Sample name
        xsecs[sample] = d[2] # Cross-section
        sumws[sample] = d[3] # Sum of weights
        num_events = d[4] # Number of events
        samples.append(sample)
        df[sample] = ROOT.RDataFrame("mini", "{}/1lep/{}/{}.1lep.root".format(dataset_path, folder, sample))
        # # Scale down the datasets if requested
        # if args.full_dataset and lumi_scale < 1.0:
        #     df[sample] = df[sample].Range(int(num_events * lumi_scale))
df
# Out:
# {'data_A': <cppyy.gbl.ROOT.RDataFrame object at 0xb079c90>,
#  'data_B': <cppyy.gbl.ROOT.RDataFrame object at 0x7f792c0024a0>,
#  'data_C': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938003fa0>,
#  'data_D': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7928003350>,
#  'mc_364156.Wmunu_PTV0_70_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f792c0065d0>,
#  'mc_364157.Wmunu_PTV0_70_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938004bc0>,
#  'mc_364158.Wmunu_PTV0_70_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938006320>,
#  'mc_364159.Wmunu_PTV70_140_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938003720>,
#  'mc_364160.Wmunu_PTV70_140_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938003380>,
#  'mc_364161.Wmunu_PTV70_140_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938002af0>,
#  'mc_364162.Wmunu_PTV140_280_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79380053b0>,
#  'mc_364163.Wmunu_PTV140_280_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938004f70>,
#  'mc_364164.Wmunu_PTV140_280_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938004700>,
#  'mc_364165.Wmunu_PTV280_500_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79380015b0>,
#  'mc_364166.Wmunu_PTV280_500_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938003560>,
#  'mc_364167.Wmunu_PTV280_500_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938005d10>,
#  'mc_364168.Wmunu_PTV500_1000': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938005520>,
#  'mc_364169.Wmunu_PTV1000_E_CMS': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800bc30>,
#  'mc_364170.Wenu_PTV0_70_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938000c60>,
#  'mc_364171.Wenu_PTV0_70_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800bd10>,
#  'mc_364172.Wenu_PTV0_70_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938001750>,
#  'mc_364173.Wenu_PTV70_140_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79380068b0>,
#  'mc_364174.Wenu_PTV70_140_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938007700>,
#  'mc_364175.Wenu_PTV70_140_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938005a60>,
#  'mc_364176.Wenu_PTV140_280_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800a1b0>,
#  'mc_364177.Wenu_PTV140_280_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938005df0>,
#  'mc_364178.Wenu_PTV140_280_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938006260>,
#  'mc_364179.Wenu_PTV280_500_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938003260>,
#  'mc_364180.Wenu_PTV280_500_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800bdf0>,
#  'mc_364181.Wenu_PTV280_500_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79380059f0>,
#  'mc_364182.Wenu_PTV500_1000': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800a020>,
#  'mc_364183.Wenu_PTV1000_E_CMS': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800a090>,
#  'mc_364184.Wtaunu_PTV0_70_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938004440>,
#  'mc_364185.Wtaunu_PTV0_70_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79380042b0>,
#  'mc_364186.Wtaunu_PTV0_70_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800ab20>,
#  'mc_364187.Wtaunu_PTV70_140_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800aeb0>,
#  'mc_364188.Wtaunu_PTV70_140_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800ac00>,
#  'mc_364189.Wtaunu_PTV70_140_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79380031f0>,
#  'mc_364190.Wtaunu_PTV140_280_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800af20>,
#  'mc_364191.Wtaunu_PTV140_280_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800cca0>,
#  'mc_364192.Wtaunu_PTV140_280_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800cd10>,
#  'mc_364193.Wtaunu_PTV280_500_CVetoBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800cf40>,
#  'mc_364194.Wtaunu_PTV280_500_CFilterBVeto': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800ab90>,
#  'mc_364195.Wtaunu_PTV280_500_BFilter': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800a300>,
#  'mc_364196.Wtaunu_PTV500_1000': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800d250>,
#  'mc_364197.Wtaunu_PTV1000_E_CMS': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800d480>,
#  'mc_363356.ZqqZll': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938009e90>,
#  'mc_363358.WqqZll': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938009d40>,
#  'mc_363359.WpqqWmlv': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800d9c0>,
#  'mc_363360.WplvWmqq': <cppyy.gbl.ROOT.RDataFrame object at 0xc980010>,
#  'mc_363489.WlvZqq': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800ac70>,
#  'mc_363490.llll': <cppyy.gbl.ROOT.RDataFrame object at 0x7f7938005ad0>,
#  'mc_363491.lllv': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800cfb0>,
#  'mc_363492.llvv': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800d020>,
#  'mc_363493.lvvv': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800dc60>,
#  'mc_361106.Zee': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800d5d0>,
#  'mc_361107.Zmumu': <cppyy.gbl.ROOT.RDataFrame object at 0x7f793800d410>,
#  'mc_361108.Ztautau': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79280586f0>,
#  'mc_410011.single_top_tchan': <cppyy.gbl.ROOT.RDataFrame object at 0x7f792802d280>,
#  'mc_410012.single_antitop_tchan': <cppyy.gbl.ROOT.RDataFrame object at 0x7f792800ac10>,
#  'mc_410025.single_top_schan': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79280582d0>,
#  'mc_410026.single_antitop_schan': <cppyy.gbl.ROOT.RDataFrame object at 0x7f792800f2f0>,
#  'mc_410013.single_top_wtchan': <cppyy.gbl.ROOT.RDataFrame object at 0x7f792804f230>,
#  'mc_410014.single_antitop_wtchan': <cppyy.gbl.ROOT.RDataFrame object at 0x7f79280587c0>,
#  'mc_410000.ttbar_lep': <cppyy.gbl.ROOT.RDataFrame object at 0x7f792805aa00>}

# %%
# Select events for the analysis

# Just-in-time compile custom helper function performing complex computations
ROOT.gInterpreter.Declare("""
bool GoodElectronOrMuon(int type, float pt, float eta, float phi, float e, float trackd0pv, float tracksigd0pv, float z0)
{
    ROOT::Math::PtEtaPhiEVector p(pt / 1000.0, eta, phi, e / 1000.0);
    if (abs(z0 * sin(p.theta())) > 0.5) return false;
    if (type == 11 && abs(eta) < 2.46 && (abs(eta) < 1.37 || abs(eta) > 1.52)) {
        if (abs(trackd0pv / tracksigd0pv) > 5) return false;
        return true;
    }
    if (type == 13 && abs(eta) < 2.5) {
        if (abs(trackd0pv / tracksigd0pv) > 3) return false;
        return true;
    }
    return false;
}
""")

for s in samples:
    # Select events with a muon or electron trigger and with a missing transverse energy larger than 30 GeV
    df[s] = df[s].Filter("trigE || trigM")\
                 .Filter("met_et > 30000")

    # Find events with exactly one good lepton
    df[s] = df[s].Define("good_lep", "lep_isTightID && lep_pt > 35000 && lep_ptcone30 / lep_pt < 0.1 && lep_etcone20 / lep_pt < 0.1")\
                 .Filter("ROOT::VecOps::Sum(good_lep) == 1")

    # Apply additional cuts in case the lepton is an electron or muon
    df[s] = df[s].Define("idx", "ROOT::VecOps::ArgMax(good_lep)")\
                 .Filter("GoodElectronOrMuon(lep_type[idx], lep_pt[idx], lep_eta[idx], lep_phi[idx], lep_E[idx], lep_trackd0pvunbiased[idx], lep_tracksigd0pvunbiased[idx], lep_z0[idx])")

# Apply luminosity, scale factors and MC weights for simulated events
for s in samples:
    if "data" in s:
        df[s] = df[s].Define("weight", "1.0")
    else:
        df[s] = df[s].Define("weight", "scaleFactor_ELE * scaleFactor_MUON * scaleFactor_LepTRIGGER * scaleFactor_PILEUP * mcWeight * {} / {} * {}".format(xsecs[s], sumws[s], lumi))

# Compute transverse mass of the W boson using the lepton and the missing transverse energy and make a histogram
ROOT.gInterpreter.Declare("""
float ComputeTransverseMass(float met_et, float met_phi, float lep_pt, float lep_eta, float lep_phi, float lep_e)
{
    ROOT::Math::PtEtaPhiEVector met(met_et, 0, met_phi, met_et);
    ROOT::Math::PtEtaPhiEVector lep(lep_pt, lep_eta, lep_phi, lep_e);
    return (met + lep).Mt() / 1000.0;
}
""")

histos = {}
for s in samples:
    df[s] = df[s].Define("mt_w", "ComputeTransverseMass(met_et, met_phi, lep_pt[idx], lep_eta[idx], lep_phi[idx], lep_E[idx])")
    histos[s] = df[s].Histo1D(ROOT.RDF.TH1DModel(s, "mt_w", 24, 60, 180), "mt_w", "weight")
histos
# Out:
# {'data_A': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x391a21c80>,
#  'data_B': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x1adbdf530>,
#  'data_C': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x28b3090a0>,
#  'data_D': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x327096490>,
#  'mc_364156.Wmunu_PTV0_70_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2b0abf470>,
#  'mc_364157.Wmunu_PTV0_70_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x326c4adc0>,
#  'mc_364158.Wmunu_PTV0_70_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x176d21d60>,
#  'mc_364159.Wmunu_PTV70_140_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2b0965cd0>,
#  'mc_364160.Wmunu_PTV70_140_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3026938b0>,
#  'mc_364161.Wmunu_PTV70_140_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2a2ce9460>,
#  'mc_364162.Wmunu_PTV140_280_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2645138b0>,
#  'mc_364163.Wmunu_PTV140_280_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x1d3c9d000>,
#  'mc_364164.Wmunu_PTV140_280_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x360d3daa0>,
#  'mc_364165.Wmunu_PTV280_500_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x27e46a880>,
#  'mc_364166.Wmunu_PTV280_500_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2e7285850>,
#  'mc_364167.Wmunu_PTV280_500_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x32708a420>,
#  'mc_364168.Wmunu_PTV500_1000': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x27e56d390>,
#  'mc_364169.Wmunu_PTV1000_E_CMS': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x302655300>,
#  'mc_364170.Wenu_PTV0_70_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x271a98ff0>,
#  'mc_364171.Wenu_PTV0_70_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x302595720>,
#  'mc_364172.Wenu_PTV0_70_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2b0acf690>,
#  'mc_364173.Wenu_PTV70_140_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2cc2a84d0>,
#  'mc_364174.Wenu_PTV70_140_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x347bce9a0>,
#  'mc_364175.Wenu_PTV70_140_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2e722f230>,
#  'mc_364176.Wenu_PTV140_280_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x30261b8e0>,
#  'mc_364177.Wenu_PTV140_280_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2b0a0bb00>,
#  'mc_364178.Wenu_PTV140_280_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3026fb200>,
#  'mc_364179.Wenu_PTV280_500_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x360cbf2f0>,
#  'mc_364180.Wenu_PTV280_500_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2d9ab0ed0>,
#  'mc_364181.Wenu_PTV280_500_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x326c9c0d0>,
#  'mc_364182.Wenu_PTV500_1000': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3025e2360>,
#  'mc_364183.Wenu_PTV1000_E_CMS': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x326d2dfe0>,
#  'mc_364184.Wtaunu_PTV0_70_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x39e2d76c0>,
#  'mc_364185.Wtaunu_PTV0_70_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2e72fb3f0>,
#  'mc_364186.Wtaunu_PTV0_70_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2f4a2af20>,
#  'mc_364187.Wtaunu_PTV70_140_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x36126cd20>,
#  'mc_364188.Wtaunu_PTV70_140_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3026b73d0>,
#  'mc_364189.Wtaunu_PTV70_140_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x28b27a7b0>,
#  'mc_364190.Wtaunu_PTV140_280_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2cc2c7cf0>,
#  'mc_364191.Wtaunu_PTV140_280_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x31820ddd0>,
#  'mc_364192.Wtaunu_PTV140_280_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x391aaff10>,
#  'mc_364193.Wtaunu_PTV280_500_CVetoBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x22c616610>,
#  'mc_364194.Wtaunu_PTV280_500_CFilterBVeto': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x22c610160>,
#  'mc_364195.Wtaunu_PTV280_500_BFilter': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x39e335de0>,
#  'mc_364196.Wtaunu_PTV500_1000': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2d984e580>,
#  'mc_364197.Wtaunu_PTV1000_E_CMS': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x29734ae80>,
#  'mc_363356.ZqqZll': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3271cf2e0>,
#  'mc_363358.WqqZll': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x326d26bd0>,
#  'mc_363359.WpqqWmlv': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x360deb700>,
#  'mc_363360.WplvWmqq': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3609a2e00>,
#  'mc_363489.WlvZqq': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x360d49340>,
#  'mc_363490.llll': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x28b276090>,
#  'mc_363491.lllv': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x22c621950>,
#  'mc_363492.llvv': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2f4addb10>,
#  'mc_363493.lvvv': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x264757770>,
#  'mc_361106.Zee': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x326c879e0>,
#  'mc_361107.Zmumu': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x356e39690>,
#  'mc_361108.Ztautau': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x326c879b0>,
#  'mc_410011.single_top_tchan': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x361283290>,
#  'mc_410012.single_antitop_tchan': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2d994f410>,
#  'mc_410025.single_top_schan': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x2cc26a450>,
#  'mc_410026.single_antitop_schan': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x360a49600>,
#  'mc_410013.single_top_wtchan': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x21e14a7f0>,
#  'mc_410014.single_antitop_wtchan': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3026828a0>,
#  'mc_410000.ttbar_lep': <cppyy.gbl.ROOT.RDF.RResultPtr<TH1D> object at 0x3612a2910>}

# %%
# Run the event loop and merge histograms of the respective processes

# RunGraphs allows to run the event loops of the separate RDataFrame graphs
# concurrently. This results in an improved usage of the available resources
# if each separate RDataFrame can not utilize all available resources, e.g.,
# because not enough data is available.
ROOT.RDF.RunGraphs([histos[s] for s in samples])

# %%
def merge_histos(label):
    h = None
    for i, d in enumerate(files[label]):
        t = histos[d[1]].GetValue()
        if i == 0: h = t.Clone()
        else: h.Add(t)
    h.SetNameTitle(label, label)
    return h

data = merge_histos("data")
wjets = merge_histos("wjets")
zjets = merge_histos("zjets")
ttbar = merge_histos("ttbar")
diboson = merge_histos("diboson")
singletop = merge_histos("singletop")

# %%
# Set styles
ROOT.gROOT.SetStyle("ATLAS")

# Create canvas
c = ROOT.TCanvas("c", "", 600, 600)
c.SetTickx(0)
c.SetTicky(0)
c.SetLogy()

# Draw stack with MC contributions
stack = ROOT.THStack()
for h, color in zip(
        [singletop, diboson, ttbar, zjets, wjets],
        [(208, 240, 193), (195, 138, 145), (155, 152, 204), (248, 206, 104), (222, 90, 106)]):
    h.SetLineWidth(1)
    h.SetLineColor(1)
    h.SetFillColor(ROOT.TColor.GetColor(*color))
    stack.Add(h)
stack.Draw("HIST")
stack.GetXaxis().SetLabelSize(0.04)
stack.GetXaxis().SetTitleSize(0.045)
stack.GetXaxis().SetTitleOffset(1.3)
stack.GetXaxis().SetTitle("m_{T}^{W#rightarrow l#nu} [GeV]")
stack.GetYaxis().SetTitle("Events")
stack.GetYaxis().SetLabelSize(0.04)
stack.GetYaxis().SetTitleSize(0.045)
stack.SetMaximum(1e10 * args.lumi_scale)
stack.SetMinimum(1)

# Draw data
data.SetMarkerStyle(20)
data.SetMarkerSize(1.2)
data.SetLineWidth(2)
data.SetLineColor(ROOT.kBlack)
data.Draw("E SAME")

# Add legend
legend = ROOT.TLegend(0.60, 0.65, 0.92, 0.92)
legend.SetTextFont(42)
legend.SetFillStyle(0)
legend.SetBorderSize(0)
legend.SetTextSize(0.04)
legend.SetTextAlign(32)
legend.AddEntry(data, "Data" ,"lep")
legend.AddEntry(wjets, "W+jets", "f")
legend.AddEntry(zjets, "Z+jets", "f")
legend.AddEntry(ttbar, "t#bar{t}", "f")
legend.AddEntry(diboson, "Diboson", "f")
legend.AddEntry(singletop, "Single top", "f")
legend.Draw()

# Add ATLAS label
text = ROOT.TLatex()
text.SetNDC()
text.SetTextFont(72)
text.SetTextSize(0.045)
text.DrawLatex(0.21, 0.86, "ATLAS")
text.SetTextFont(42)
text.DrawLatex(0.21 + 0.16, 0.86, "Open Data")
text.SetTextSize(0.04)
# text.DrawLatex(0.21, 0.80, "#sqrt{{s}} = 13 TeV, {:.2f} fb^{{-1}}".format(lumi * args.lumi_scale / 1000.0))
text.DrawLatex( 0.21, 0.80, "#sqrt{{s}} = 13 TeV, {:.2f} fb^{{-1}}".format( lumi / 1000.0 ) )

c.Draw()
